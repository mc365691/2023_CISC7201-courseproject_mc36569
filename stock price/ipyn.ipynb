# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import yfinance as yf

# %%
start ='2016-01-01'
end = '2022-12-31'
#apple company stock name
stock = 'AAPL'
#data can download from
data=yf.download(stock, start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#       level_0  index       Date        Open        High         Low  \
# 0           0      0 2016-01-04   25.652500   26.342501   25.500000
# 1           1      1 2016-01-05   26.437500   26.462500   25.602501
# 2           2      2 2016-01-06   25.139999   25.592501   24.967501
# 3           3      3 2016-01-07   24.670000   25.032499   24.107500
# 4           4      4 2016-01-08   24.637501   24.777500   24.190001
# ...       ...    ...        ...         ...         ...         ...
# 1757     1757   1757 2022-12-23  130.919998  132.419998  129.639999
# 1758     1758   1758 2022-12-27  131.380005  131.410004  128.720001
# 1759     1759   1759 2022-12-28  129.669998  131.029999  125.870003
# 1760     1760   1760 2022-12-29  127.989998  130.479996  127.730003
# 1761     1761   1761 2022-12-30  128.410004  129.949997  127.430000
#
#            Close   Adj Close     Volume
# 0      26.337500   23.977478  270597600
# 1      25.677500   23.376617  223164000
# 2      25.174999   22.919142  273829600
# 3      24.112499   21.951847  324377600
# 4      24.240000   22.067923  283192000
# ...          ...         ...        ...
# 1757  131.860001  131.127060   63814900
# 1758  130.029999  129.307236   69007800
# 1759  126.040001  125.339417   85438400
# 1760  129.610001  128.889572   75703700
# 1761  129.929993  129.207779   77034200
#
# [1762 rows x 9 columns]

# %%
ma_100_days = data.Close.rolling(100).mean()

# %%
plt.figure(figsize=(9,7))
plt.plot(ma_100_days, 'y')
plt.plot(data.Close, 'g')
plt.show()
